# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

#Setting the style for visualizations
sns.set_theme(style="whitegrid")

# Load the CSV
df = pd.read_csv("../data/Sudan/sudan.csv")

# Add Country column
df["Country"] = "Sudan"

# Convert YEAR and DOY to datetime
# Format %Y%j handles Year + Day of Year (1-366)
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")

# Extract Month as a separate column
df["Month"] = df["Date"].dt.month

#Printing the size of the data and viewing the top 5 rows of the data
print("Size of the dataset for Sudan is", df.shape)
df.head()
# Out:
# Size of the dataset for Sudan is (4108, 15)
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1  2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2  2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3  2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4  2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
#
#    WS2M_MAX     PS  QV2M Country       Date  Month
# 0      5.12  96.54  6.08   Sudan 2015-01-01      1
# 1      5.10  96.67  4.31   Sudan 2015-01-02      1
# 2      6.24  96.77  6.42   Sudan 2015-01-03      1
# 3      6.96  96.93  3.06   Sudan 2015-01-04      1
# 4      5.82  96.85  2.86   Sudan 2015-01-05      1

# %%
# 1. Replace NASA sentinel values
df.replace(-999, np.nan, inplace=True)

# 2. Handle Duplicates and print them if there are any
duplicates = df.duplicated().sum()
print(f"Total Duplicate rows found: {duplicates}")
df.drop_duplicates(inplace=True)

# 3. Missing Value Report
null_report = df.isna().sum()
null_percent = (null_report / len(df)) * 100
print("Percentage of missing values per column:")
print(null_percent) 

# Run summary statistics for all numeric columns
df.describe()
# Out:
# Total Duplicate rows found: 0
# Percentage of missing values per column:
# YEAR           0.0
# DOY            0.0
# T2M            0.0
# T2M_MAX        0.0
# T2M_MIN        0.0
# T2M_RANGE      0.0
# PRECTOTCORR    0.0
# RH2M           0.0
# WS2M           0.0
# WS2M_MAX       0.0
# PS             0.0
# QV2M           0.0
# Country        0.0
# Date           0.0
# Month          0.0
# dtype: float64
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    28.759007    36.773914    21.508510
# min    2015.000000     1.000000    13.180000    21.040000     5.930000
# 25%    2017.000000    86.000000    25.560000    33.730000    17.497500
# 50%    2020.000000   179.000000    29.160000    37.020000    22.890000
# 75%    2023.000000   272.000000    32.510000    40.330000    25.430000
# max    2026.000000   366.000000    37.990000    45.960000    32.170000
# std       3.248907   106.294767     4.681305     4.400065     5.091142
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     15.265404     0.643875    31.359192     3.484253     5.157378
# min       3.420000     0.000000     4.690000     0.610000     1.030000
# 25%      13.280000     0.000000    17.407500     2.730000     4.267500
# 50%      15.810000     0.000000    26.630000     3.490000     5.120000
# 75%      17.680000     0.010000    40.535000     4.220000     6.020000
# max      22.480000    66.490000    87.160000     7.150000     9.050000
# std       3.298919     3.057672    17.851849     1.040667     1.280238
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean     96.346273     7.864557  2020-08-15 12:00:00     6.423564
# min      95.660000     1.160000  2015-01-01 00:00:00     1.000000
# 25%      96.160000     3.730000  2017-10-23 18:00:00     3.000000
# 50%      96.310000     5.895000  2020-08-15 12:00:00     6.000000
# 75%      96.510000    12.500000  2023-06-08 06:00:00     9.000000
# max      97.310000    19.440000  2026-03-31 00:00:00    12.000000
# std       0.266927     4.880934                  NaN     3.477046

# %% [markdown]
# Data Quality Interpretation:
#
# * Missing Values: After replacing NASA sentinel values (-999), the dataset contains 0% missing values across all columns. This indicates a high-quality, coninuous record for the Sudan climate data.
# * Duplicates: No duplicate rows were detected, ensuring that time-series observations are unique.
# * Summary Stats: The average temprature is approximately 28.759007°C, with a maximum of 36.773914°C

# %%
from scipy import stats
import numpy as np

# Columns to check for outliers
cols_to_check = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M', 'WS2M_MAX']

# Calculate Z-scores (number of standard deviations away from the mean)
z_scores = np.abs(stats.zscore(df[cols_to_check]))

# Identify rows where any column has a Z-score > 3
outlier_rows = (z_scores > 3).any(axis=1)
outlier_count = outlier_rows.sum()

print(f"Total rows flagged as outliers (|Z| > 3): {outlier_count}")

# Display outlier counts per specific column
outliers_per_col = (z_scores > 3).sum()
print("\nOutliers detected per column:", outliers_per_col)
print("")


## The following code displays the first 20 rows that contain
## atleast one outlier, highlighing the extreme values.

# Convert the mask to a DataFrame so we can use Pandas tools
outlier_mask = (z_scores > 3)
outlier_mask_df = pd.DataFrame(outlier_mask, columns=cols_to_check)

# This creates a summary showing which columns were outliers for the flagged rows
# We filter it to only show rows where at least one value is True
flagged_only = outlier_mask_df[outlier_mask_df.any(axis=1)]

print(f"Showing the 'culprit' columns for the first 20 outliers:")
for index, row in flagged_only.head(20).iterrows():
    # Get the column names where the value is True
    flagged_cols = row[row == True].index.tolist()
    
    # Get the date from the original dataframe using the index
    obs_date = df.loc[index, 'Date'].date()
    
    print(f"Row {index} (Date: {obs_date}): Outliers in {flagged_cols}")
# Out:
# Total rows flagged as outliers (|Z| > 3): 84
#
# Outliers detected per column: 91
#
# Showing the 'culprit' columns for the first 20 outliers:
# Row 8 (Date: 2015-01-09): Outliers in ['T2M', 'T2M_MAX']
# Row 9 (Date: 2015-01-10): Outliers in ['T2M', 'T2M_MAX']
# Row 10 (Date: 2015-01-11): Outliers in ['T2M', 'T2M_MAX', 'T2M_MIN']
# Row 223 (Date: 2015-08-12): Outliers in ['PRECTOTCORR']
# Row 392 (Date: 2016-01-28): Outliers in ['T2M_MAX']
# Row 557 (Date: 2016-07-11): Outliers in ['PRECTOTCORR']
# Row 562 (Date: 2016-07-16): Outliers in ['PRECTOTCORR']
# Row 575 (Date: 2016-07-29): Outliers in ['PRECTOTCORR']
# Row 585 (Date: 2016-08-08): Outliers in ['PRECTOTCORR']
# Row 586 (Date: 2016-08-09): Outliers in ['PRECTOTCORR']
# Row 596 (Date: 2016-08-19): Outliers in ['PRECTOTCORR']
# Row 835 (Date: 2017-04-15): Outliers in ['WS2M']
# Row 959 (Date: 2017-08-17): Outliers in ['PRECTOTCORR']
# Row 968 (Date: 2017-08-26): Outliers in ['PRECTOTCORR']
# Row 969 (Date: 2017-08-27): Outliers in ['PRECTOTCORR']
# Row 1299 (Date: 2018-07-23): Outliers in ['PRECTOTCORR']
# Row 1300 (Date: 2018-07-24): Outliers in ['PRECTOTCORR']
# Row 1305 (Date: 2018-07-29): Outliers in ['PRECTOTCORR']
# Row 1322 (Date: 2018-08-15): Outliers in ['PRECTOTCORR']
# Row 1343 (Date: 2018-09-05): Outliers in ['PRECTOTCORR']

# %% [markdown]
# Outlier Analysis & Handling Decision:
#
# * Detection Methodology: Using the Z-score method (|Z|>3), we identified 84 rows containing outliers. A closer inspection of these outliers reveals clear seasonal patterns.
# * Key Observations from Flagged Data:
#
#     1. Winter Thermal Spikes (Jan 2015 & Jan 2016): Rows 8–10 and Row 392 flag T2M and T2M_MAX. These outliers represent unusual "heat pulses" during the typically cool Sudanese winter, which can impact local agriculture and water evaporation rates.
#
#     2. The Summer Deluge (July–September): A massive majority of the outliers (e.g., Rows 557–596, 959–969, 1299–1343) are concentrated in the summer months and flag PRECTOTCORR (Precipitation).
#
#         * Scientific Context: This highlights Sudan's "Flash Flood" risk. In an arid landscape, rainfall is not a daily occurrence but happens in extreme, isolated events that deviate significantly from the baseline (Z>3).
#
#     3. Dust Storm Signature (April 2017): Row 835 flags WS2M (Wind Speed) in isolation. A sudden wind outlier in April, before the rainy season, is a strong statistical indicator of a Haboob (intense dust storm).
# * Decision: I chose to RETAIN all 84 outlier rows.
# * Reasoning: Climate change analysis in Africa is largely focused on the frequency and intensity of extreme events. The clustered nature of these outliers provides essential data on weather volatitlity. Dropping these points would lead to an understimation of the climate risks that COP32 aims to address.

# %%
# Exporting the cleaned DataFrame
import os

# 1. Ensure the data directory exists (just in case)
os.makedirs("../data", exist_ok=True)

# 2. Define the filename dynamically
clean_filename = f"../data/Sudan/sudan_clean.csv"

# 3. Export to CSV
# index=False is crucial so you don't add an extra 'Unnamed: 0' column
df.to_csv(clean_filename, index=False)

print(f"Successfully exported cleaned data to: {clean_filename}")
# Out:
# Successfully exported cleaned data to: ../data/Sudan/sudan_clean.csv

# %% [markdown]
# Data Export Note: The cleaned dataset has been exported to data/Sudan/sudan_clean.csv. This file is explicitly excluded from version control via .gitignore to prevent data leakage while maintaining a reproducible cleaning pipeline.

# %%
## Temperature Line Chart (T2M) with annotations
import matplotlib.pyplot as plt
import pandas as pd

# Ensure Date is datetime and set as index
df['Date'] = pd.to_datetime(df['Date'])
temp_df = df.set_index('Date')['T2M'].resample('MS').mean()

# Find warmest and coolest for annotation
warmest_date = temp_df.idxmax()
warmest_val = temp_df.max()
coolest_date = temp_df.idxmin()
coolest_val = temp_df.min()

plt.figure(figsize=(14, 7))
plt.plot(temp_df.index, temp_df, color='#d62728', linewidth=2, label='Monthly Avg Temp')

# Annotations
plt.annotate(f'Warmest: {warmest_val:.1f}°C\n({warmest_date.strftime("%b %Y")})', 
             xy=(warmest_date, warmest_val), xytext=(-100, 20),
             textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black', connectionstyle="arc3,rad=.2"), fontsize=10, fontweight='bold')

plt.annotate(f'Coolest: {coolest_val:.1f}°C\n({coolest_date.strftime("%b %Y")})', 
             xy=(coolest_date, coolest_val), xytext=(40, -40),
             textcoords='offset points', arrowprops=dict(arrowstyle='->', color='blue', connectionstyle="arc3,rad=-.2"), fontsize=10, fontweight='bold')

plt.ylim(temp_df.min() - 5, temp_df.max() + 8)
plt.title('Sudan: Monthly Average Temperature (2015-2026)', fontsize=14)
plt.ylabel('Temperature (°C)')
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()

import matplotlib.dates as mdates

# Filter data for a 2-year window to see months clearly for better analysis
# 1) 2020 - 2022

plt.figure(figsize=(15, 6))

zoom_df = temp_df['2020':'2022'] 

plt.plot(zoom_df.index, zoom_df, marker='o', color='#d62728', linewidth=2)

# This is the magic part: Force month labels
plt.gca().xaxis.set_major_locator(mdates.MonthLocator()) # Mark every month
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b')) # Show 'Jan', 'Feb', etc.

# Add the Year below the months
plt.gca().xaxis.set_minor_locator(mdates.YearLocator())
plt.gca().xaxis.set_minor_formatter(mdates.DateFormatter('\n\n%Y'))

plt.title('Monthly Temperature Signature (2020-2022 Deep Dive)', fontsize=14)
plt.ylabel('Temperature (°C)')
plt.grid(True, alpha=0.3)
plt.show()

# 2) 2024 - 2026

plt.figure(figsize=(15, 6))

zoom_df = temp_df['2024':'2026'] 

plt.plot(zoom_df.index, zoom_df, marker='o', color='#d62728', linewidth=2)

# This is the magic part: Force month labels
plt.gca().xaxis.set_major_locator(mdates.MonthLocator()) # Mark every month
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b')) # Show 'Jan', 'Feb', etc.

# Add the Year below the months
plt.gca().xaxis.set_minor_locator(mdates.YearLocator())
plt.gca().xaxis.set_minor_formatter(mdates.DateFormatter('\n\n%Y'))

plt.title('Monthly Temperature Signature (2024-2026 Deep Dive)', fontsize=14)
plt.ylabel('Temperature (°C)')
plt.grid(True, alpha=0.3)
plt.show()

## Rainfall Bar Chart (PRECTOTCORR)

# Calculate Monthly Total Rainfall
rain_df = df.set_index('Date')['PRECTOTCORR'].resample('MS').sum()

# Identify peak month
peak_rain_date = rain_df.idxmax()
peak_rain_val = rain_df.max()

plt.figure(figsize=(14, 7))
plt.bar(rain_df.index, rain_df, width=22, color='#1f77b4', alpha=0.8, label='Monthly Rainfall')

# Annotate Peak
plt.annotate(f'Peak Rain: {peak_rain_val:.1f}mm\n({peak_rain_date.strftime("%b %Y")})', 
             xy=(peak_rain_date, peak_rain_val), xytext=(-120, 10),
             textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black', lw=1.5), fontsize=10, fontweight='bold', bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", alpha=0.8))

plt.ylim(0, rain_df.max()*1.3)
plt.title('Sudan: Monthly Total Rainfall (2015-2026)', fontsize=16, pad=30)
plt.ylabel('Total Precipitation (mm)')
plt.xlabel('Year')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# Analysis of Climate Trends (2015-2026):
#
# * Seasonal Temperature and Rainfall Dynamics
#     * The "Pre-Monsoon" Heat Peak
#
#         * Thermal Maximum: The historical warmest month was June 2024. Across most years, temperatures rise steadily from January to a peak in June.
#
#         * The Monsoon Cool-Down: There is a consistent temperature drop from June to August. This coincides with the peak rainfall (Historical Peak: July 2021). The rain and increased cloud cover provide a brief but vital respite from the desert heat.
#
#         * The "Second Summer": Post-August, temperatures rise again until October before the final winter decline into December.
#
#         * 2022 Anomaly: Unlike other years that peak in June, 2022 saw an early peak in May, followed by a much earlier and sustained cooling through August, suggesting an exceptionally early or active monsoon arrival that year.

# %%
## Correlation Heatmap

import seaborn as sns

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
corr_matrix = df[numeric_cols].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Climate Variables (Sudan)', fontsize=15, pad=20)
plt.show()

## Scatter Plots

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: T2M vs RH2M
sns.regplot(data=df, x='T2M', y='RH2M', ax=ax1, 
            scatter_kws={'alpha':0.3, 'color':'orange'}, line_kws={'color':'red'})
ax1.set_title('Temperature vs. Relative Humidity')
ax1.set_xlabel('Temperature (°C)')
ax1.set_ylabel('Relative Humidity (%)')

# Plot 2: T2M_RANGE vs WS2M
sns.regplot(data=df, x='T2M_RANGE', y='WS2M', ax=ax2, 
            scatter_kws={'alpha':0.3, 'color':'teal'}, line_kws={'color':'black'})
ax2.set_title('Temperature Range vs. Wind Speed')
ax2.set_xlabel('Daily Temp Range (°C)')
ax2.set_ylabel('Wind Speed (m/s)')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Interpreting the Top 3 Correlations
#
# 1. T2M and T2M_MAX (0.94) — [Strong Positive Correlation]:- In a desert environment, the daily average is heavily dictated by the afternoon peak due to lack of cloud cover.
#
# 2. RH2M and QV2M (0.94) — [Strong Positive Correlation]:- This shows that when humidity rises in Sudan, it is due to a physical influx of water vapor (likely from the south), rather than just temperature changes.
#
# 3. T2M and T2M_MAX (0.93) — [Strong Positive Correlation]:- A secondary check of these two confirms the stability of these heat patterns across the multi-year dataset.
#
# * Scatter Plot
#
#     1. Temperature vs. Humidity (The Desert Shift): The trend shows a slight upward slope from (13°C,30%) to (38°C,32%).
#
#         * Observation: This is rare; it indicates that Sudan’s hottest days often coincide with a slight increase in humidity (the "Monsoon" heat). However, the most saturated points form a line between 25°C and 37°C with humidity varying wildly up to 80%, representing the volatile transition from bone-dry heat to tropical monsoon air.
#
#     2. Temperature vs. Wind Speed: An inverse relationship is noted.
#         * As the air heats up to its extreme (22.5°C anomaly/local scale), wind speeds slightly decrease. The data is most saturated between 12.5°C and 21°C, suggesting that Sudan’s wind is most active during moderate-temperature periods.

# %%
## Histogtam of Rainfall (PRECTOTCORR)

plt.figure(figsize=(10, 6))

# We add a tiny constant (1e-6) to avoid log(0) errors for dry days
sns.histplot(df['PRECTOTCORR'] + 1e-6, kde=True, color='blue', log_scale=True)

plt.title('Distribution of Daily Rainfall (Log Scale)', fontsize=14)
plt.xlabel('Rainfall (mm) - Log Scale')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.3)
plt.show()


## Bubble Chart: T2M vs. RH2M (Size=Rain)

plt.figure(figsize=(12, 8))

# Create the scatter/bubble plot
scatter = plt.scatter(df['T2M'], df['RH2M'], 
                      s=df['PRECTOTCORR']*5, # Scaling factor to make bubbles visible
                      alpha=0.4, 
                      c=df['PRECTOTCORR'], # Color also mapped to rain for clarity
                      cmap='Blues', 
                      edgecolors='grey', 
                      linewidth=0.5)

# Add a colorbar to show rain intensity
cbar = plt.colorbar(scatter)
cbar.set_label('Rainfall Intensity (mm)')

plt.title('Relationship: Temperature vs. Humidity (Bubble Size = Rainfall)', fontsize=14)
plt.xlabel('Temperature (°C)')
plt.ylabel('Relative Humidity (%)')
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# * Rainfall Distribution & Variable Interaction
#
#     * Rainfall Histogram: "All or Nothing"
#
#         * Dry Frequency: Sudan has the most extreme "Dry-Day" bar of all countries, with a frequency of 3,000 at 10−6. This confirms that for the vast majority of the year, there is absolutely no recorded precipitation.
#
#         * The Rainfall Bell: The "hump" between 10−3 and 101 is very low, failing to even reach a frequency of 100. This statistically proves that Sudan’s water security is reliant on very few, highly intense events rather than consistent rain.
#
#     * Bubble Plot: The Arid Core
#
#         * The Desert Heart: A unique "Big Bubble" exists between 30°C and 35°C with very low humidity (20%–40%). This is the "Heat Stress Zone" that defines the Sudanese climate.
#
#         * Limited Coverage: Unlike Nigeria’s saturated plot, Sudan’s bubbles are sparse. They only appear in a specific window of 25°C–35°C and 20%–85% humidity. This sparse distribution highlights a climate that jumps between extremes—from dry heat to humid heat—with very little "mild" weather in between.
